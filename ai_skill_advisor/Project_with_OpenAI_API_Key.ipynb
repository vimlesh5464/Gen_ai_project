# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("OPENAI_API_KEY")

# %%
llm = ChatOpenAI(model_name="gpt-4o", openai_api_key=api_key)

# %%
prompt=PromptTemplate.from_template("""
Suggest top {number} high-demand skills for a {role} in {year}.
Experience level: {level}
""")

# %%
chains = prompt | llm | StrOutputParser()

# %%
res = chains.invoke({
  "number":"2",
  "role":"ai",
  "year":"2025",
  "level":"fresher"
  })

# %%
print(res)
# Out:
# As we look towards 2025, the field of AI is expected to continue evolving rapidly. For a fresher entering the industry, focusing on the following high-demand skills could be particularly advantageous:
#
# 1. **Ethical AI and Responsible AI Development**: As AI technologies become more integrated into everyday life, there is an increasing demand for AI solutions that are ethical, transparent, and fair. Understanding the principles of responsible AI development, bias mitigation, privacy concerns, and regulatory compliance will be crucial. Skills like developing AI models with fairness and interpretability in mind can set you apart.
#
# 2. **Automated Machine Learning (AutoML)**: AutoML tools are gaining popularity as they enable even those with limited expertise in machine learning to build effective models. By becoming proficient in AutoML, a fresher can quickly prototype and deploy models, thus contributing value to teams working on a variety of projects. Familiarity with tools and platforms that offer AutoML capabilities will be beneficial.
#
# Focusing on these areas can help a fresher stand out in the competitive AI job market of the future.
