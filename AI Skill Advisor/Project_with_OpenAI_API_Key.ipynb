# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os
load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
os.getenv("OPENAI_API_KEY")
# Out:
# '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'

# %%
llm = ChatOpenAI(model="gpt-4o")

# %%
prompt=PromptTemplate.from_template("""
Suggest top {number} high-demand skills for a {role} in {year}.
Experience level: {level}
""")

# %%
chains = prompt | llm | StrOutputParser()

# %%
res = chains.invoke({
  "number":"2",
  "role":"ai",
  "year":"2025",
  "level":"fresher"
  })

# %%
print(res)
# Out:
# Predicting the top high-demand skills for AI in 2025 can be challenging given the rapid pace of technological advancement, but based on current trends and projected developments, here are five skills that are likely to be in high demand for freshers entering the AI field:
#
# 1. **Machine Learning and Deep Learning**:
#    - Understanding core concepts and algorithms in machine learning and deep learning is fundamental. Familiarity with frameworks like TensorFlow, PyTorch, and scikit-learn will be valuable. As AI continues to evolve, freshers with strong foundations in these areas will be in demand.
#
# 2. **Data Manipulation and Analysis**:
#    - Skills in handling and processing large datasets are critical. Proficiency in programming languages such as Python and tools like Pandas, NumPy, and SQL is essential. Data cleaning, feature engineering, and exploratory data analysis will be important for building effective AI models.
#
# 3. **Natural Language Processing (NLP)**:
#    - With the growth of conversational agents and language models, understanding NLP techniques and tools (e.g., BERT, GPT, and Transformer models) will be highly desirable. Freshers with capabilities in language understanding and generation will find numerous opportunities.
#
# 4. **AI Ethics and Bias Mitigation**:
#    - As AI systems become more prevalent, addressing issues related to ethics, bias, and fairness is crucial. Freshers with an understanding of these topics and techniques for mitigating bias in AI systems will be sought after to ensure responsible AI deployment.
#
# 5. **Cloud Computing and AI Deployment**:
#    - Familiarity with cloud platforms like AWS, Google Cloud, and Azure for deploying and scaling AI models will be in demand. Understanding the integration of AI services and managing AI workloads in the cloud environment will be valuable skills for freshers.
#
# By focusing on these areas, freshers can equip themselves with the skills needed to navigate and succeed in the rapidly evolving AI landscape of 2025. Additionally, staying updated with emerging trends and technologies in AI will be crucial for continuous growth and relevance in the field.
